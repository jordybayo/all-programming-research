# %% [markdown]
# # importing data

# %%
#import pandas library

import pandas as pd
#read dataFrame and stor into a dataFrame
cars = pd.read_csv("GOOG.csv")
cars
# Out:
#            Date         Open         High          Low        Close  \
# 0    2017-01-03   778.809998   789.630005   775.799988   786.140015
# 1    2017-01-04   788.359985   791.340027   783.159973   786.900024
# 2    2017-01-05   786.080017   794.479980   785.020020   794.020020
# 3    2017-01-06   795.260010   807.900024   792.203979   806.150024
# 4    2017-01-09   806.400024   809.966003   802.830017   806.650024
# 5    2017-01-10   807.859985   809.130005   803.510010   804.789978
# 6    2017-01-11   805.000000   808.150024   801.369995   807.909973
# 7    2017-01-12   807.140015   807.390015   799.169983   806.359985
# 8    2017-01-13   807.479980   811.223999   806.690002   807.880005
# 9    2017-01-17   807.080017   807.140015   800.369995   804.609985
# 10   2017-01-18   805.809998   806.205017   800.989990   806.070007
# 11   2017-01-19   805.119995   809.479980   801.799988   802.174988
# 12   2017-01-20   806.909973   806.909973   801.690002   805.020020
# ...

# %%
#type
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
#head
cars.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  778.809998  789.630005  775.799988  786.140015  786.140015
# 1  2017-01-04  788.359985  791.340027  783.159973  786.900024  786.900024
# 2  2017-01-05  786.080017  794.479980  785.020020  794.020020  794.020020
# 3  2017-01-06  795.260010  807.900024  792.203979  806.150024  806.150024
# 4  2017-01-09  806.400024  809.966003  802.830017  806.650024  806.650024
#
#     Volume
# 0  1657300
# 1  1073000
# 2  1335200
# 3  1640200
# 4  1274600

# %%
#DETAILED HEAD
cars.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  778.809998  789.630005  775.799988  786.140015  786.140015
# 1  2017-01-04  788.359985  791.340027  783.159973  786.900024  786.900024
# 2  2017-01-05  786.080017  794.479980  785.020020  794.020020  794.020020
# 3  2017-01-06  795.260010  807.900024  792.203979  806.150024  806.150024
# 4  2017-01-09  806.400024  809.966003  802.830017  806.650024  806.650024
# 5  2017-01-10  807.859985  809.130005  803.510010  804.789978  804.789978
# 6  2017-01-11  805.000000  808.150024  801.369995  807.909973  807.909973
# 7  2017-01-12  807.140015  807.390015  799.169983  806.359985  806.359985
# 8  2017-01-13  807.479980  811.223999  806.690002  807.880005  807.880005
# 9  2017-01-17  807.080017  807.140015  800.369995  804.609985  804.609985
#
#     Volume
# 0  1657300
# 1  1073000
# 2  1335200
# 3  1640200
# 4  1274600
# 5  1176800
# 6  1065900
# 7  1353100
# 8  1099200
# 9  1362100

# %%
#last records
cars.tail()
cars.tail(10)
# Out:
#            Date         Open         High          Low        Close  \
# 640  2019-07-22  1133.449951  1139.250000  1124.239990  1138.069946
# 641  2019-07-23  1144.000000  1146.900024  1131.800049  1146.209961
# 642  2019-07-24  1131.900024  1144.000000  1126.989990  1137.810059
# 643  2019-07-25  1137.819946  1141.699951  1120.920044  1132.119995
# 644  2019-07-26  1224.040039  1265.550049  1224.000000  1250.410034
# 645  2019-07-29  1241.050049  1247.369995  1228.229980  1239.410034
# 646  2019-07-30  1225.410034  1234.869995  1223.300049  1225.140015
# 647  2019-07-31  1223.000000  1234.000000  1207.764038  1216.680054
# 648  2019-08-01  1214.030029  1234.109985  1205.719971  1209.010010
# 649  2019-08-02  1200.739990  1206.900024  1188.939941  1193.989990
#
#        Adj Close   Volume
# 640  1138.069946  1301500
# 641  1146.209961  1093700
# 642  1137.810059  1589800
# 643  1132.119995  2209800
# 644  1250.410034  4805800
# 645  1239.410034  2223700
# 646  1225.140015  1453300
# ...

# %%
# view number of rows and columns
cars.shape
# Out:
# (650, 7)

# %%
# print a consize summary
cars.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 7 columns):
# Date         650 non-null object
# Open         650 non-null float64
# High         650 non-null float64
# Low          650 non-null float64
# Close        650 non-null float64
# Adj Close    650 non-null float64
# Volume       650 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 35.6+ KB

# %%
# mean ou moyenne de chaque colonne
cars.mean()
# Out:
# Open         1.045216e+03
# High         1.054355e+03
# Low          1.036060e+03
# Close        1.045656e+03
# Adj Close    1.045656e+03
# Volume       1.585609e+06
# dtype: float64

# %%
#standart deviation
cars.std()
# Out:
# Open            120.674417
# High            122.433141
# Low             118.920862
# Close           120.676959
# Adj Close       120.676959
# Volume       698960.398715
# dtype: float64

# %%
#max
cars.max()
# Out:
# Date         2019-08-02
# Open               1274
# High            1289.27
# Low              1266.3
# Close           1287.58
# Adj Close       1287.58
# Volume          6207000
# dtype: object

# %%
#min
cars.min()
# Out:
# Date         2017-01-03
# Open             778.81
# High             789.63
# Low               775.8
# Close            786.14
# Adj Close        786.14
# Volume           537000
# dtype: object

# %%
#count numbers of recors and NaN
cars.count()
# Out:
# Date         650
# Open         650
# High         650
# Low          650
# Close        650
# Adj Close    650
# Volume       650
# dtype: int64

# %%
#describe statictics summary
cars.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   650.000000   650.000000   650.000000   650.000000   650.000000
# mean   1045.216052  1054.354763  1036.059835  1045.656121  1045.656121
# std     120.674417   122.433141   118.920862   120.676959   120.676959
# min     778.809998   789.630005   775.799988   786.140015   786.140015
# 25%     952.984985   959.721512   946.010025   950.990006   950.990006
# 50%    1062.429993  1074.575012  1048.859985  1064.449951  1064.449951
# 75%    1137.737457  1146.368256  1127.270508  1138.657471  1138.657471
# max    1274.000000  1289.270020  1266.295044  1287.579956  1287.579956
#
#              Volume
# count  6.500000e+02
# mean   1.585609e+06
# std    6.989604e+05
# min    5.370000e+05
# 25%    1.169850e+06
# 50%    1.395500e+06
# 75%    1.814975e+06
# max    6.207000e+06
